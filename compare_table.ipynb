# %%
import pandas as pd

# if you kept summarize() and print_markdown_table() in compare_grammar_vs_hybrid.py
from comparison import load_eval_inputs, run_grammar_only, run_hybrid, summarize

inputs = load_eval_inputs("data/eval_input.txt")

grammar_results = run_grammar_only(inputs)
hybrid_results  = run_hybrid(inputs)

rows = [
    summarize("Grammar-only", grammar_results),
    summarize("Hybrid", hybrid_results),
]

df = pd.DataFrame(rows)
df
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/hp/HybridMind/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
